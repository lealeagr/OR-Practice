# %%
# http://apmonitor.com/che263/index.php/Main/PythonOptimization

import pandas as pd


##
pd_JRP = pd.read_excel("setB-001.xlsx")
print(pd_JRP.columns)
pd_JRP.head()
##
# Out:
# Index(['Item-ID(String)', 'Casepack-Size(int)', 'minVolumePerOrder(int)',
#        'maxVolumePerOrder(int)', 'Demand1(int)', 'Demand2', 'Demand3',
#        'Demand4', 'Demand5', 'Demand6', 'Demand7', 'Demand8', 'Demand9',
#        'Demand10', 'Demand11', 'Demand12', 'Demand13', 'Demand14', 'Demand15',
#        'Demand16', 'Demand17', 'Demand18', 'Demand19', 'Demand20',
#        'MeanDemand(double)', 'HoldingCostsPerUnit1(double)',
#        'MinorOrderingCosts1', 'MinorOrderingCosts2', 'MinorOrderingCosts3',
#        'MinorOrderingCosts4', 'MinorOrderingCosts5', 'MinorOrderingCosts6',
#        'MinorOrderingCosts7', 'MinorOrderingCosts8', 'MinorOrderingCosts9',
#        'MinorOrderingCosts10', 'MinorOrderingCosts11', 'MinorOrderingCosts12',
#        'MinorOrderingCosts13', 'MinorOrderingCosts14', 'MinorOrderingCosts15',
#        'MinorOrderingCosts16', 'MinorOrderingCosts17', 'MinorOrderingCosts18',
#        'MinorOrderingCosts19', 'MinorOrderingCosts20',
#        'Weight Contribution(int)', 'Value Contribution(int)'],
#       dtype='object')
#   Item-ID(String)  Casepack-Size(int)  minVolumePerOrder(int)  \
# 0          Item.0                   1                       1
# 1          Item.1                   1                       1
# 2          Item.2                   1                       1
# 3          Item.3                   1                       1
# 4          Item.4                   1                       1
#
#    maxVolumePerOrder(int)  Demand1(int)  Demand2  Demand3  Demand4  Demand5  \
# 0                     inf            50       40       30       20       50
# 1                     inf           209      217      200      205      212
# 2                     inf            54       82       26       30       39
# 3                     inf           193      193      206      190      185
# 4                     inf            45      607        0       69     1829
#
#    Demand6           ...             MinorOrderingCosts13  \
# 0       30           ...                              NaN
# 1      187           ...                              NaN
# 2       46           ...                              NaN
# 3      198           ...                             44.6
# 4        0           ...                            150.4
#
#    MinorOrderingCosts14  MinorOrderingCosts15  MinorOrderingCosts16  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                  44.6                  44.6                  30.7
# 4                 167.7                 150.4                 158.0
#
#    MinorOrderingCosts17  MinorOrderingCosts18  MinorOrderingCosts19  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   inf                  44.6             46.700000
# 4                   inf                 150.4                   inf
#
#    MinorOrderingCosts20  Weight Contribution(int)  Value Contribution(int)
# 0                   NaN                     0.008                    0.085
# 1                   NaN                     0.007                    0.047
# 2                   NaN                     0.005                    0.028
# 3                  27.5                     0.003                    0.085
# 4                 150.4                     0.011                    0.041
#
# [5 rows x 48 columns]

# %%
D = {}
D = list(pd_JRP['MeanDemand(double)'])
print('MeanDemand')
print(D)
h = {}
h = list(pd_JRP['HoldingCostsPerUnit1(double)'])
print('HoldingCostsPerUnit1')
print(h)
s = {}
s = list(pd_JRP['MinorOrderingCosts1'])# determining how to fill out the missing data, one suggestion, give the average value
print('MinorOrderingCosts1')
print(s)
print(len(s))
# h=[2,1,4]        # holding costs
# D=[10,20,5]      # Demand rate
# s=[2.0,3.0,4.0]  # The minor setup costs

items = len(s)  # items
S=14020.0       # The major setup cost
# Out:
# MeanDemand
# [20.0, 193.9, 30.2, 141.5, 44.3, 7.7, 80.6, 115.9, 13.2, 89.9, 60.9, 40.6, 17.6, 157.3, 4.7, 50.8, 0.4, 3.5, 12.2, 49.1, 2.8, 51.2, 6.6, 16.4, 8.2, 56.3, 22.7, 11.6, 134.3, 77.3, 1.6, 24.5, 29.7, 167.0, 13.6, 1.0, 13.6, 3.0, 14.5, 87.9, 16.5, 125.6, 1.4, 184.7, 53.6, 11.4, 47.0, 80.9, 86.2, 29.3, 54.0, 29.0, 18.0, 137.1, 2.1, 129.2, 28.0, 23.9, 6.6, 2.5, 3.3, 71.0, 10.7, 1.6, 2.8, 11.8, 16.8, 98.1, 28.0, 2.5, 9.0, 15.3, 22.2, 31.2, 26.5, 17.9, 0.6, 152.9, 114.3, 46.3, 46.8, 57.7, 1.0, 15.2, 14.4, 2.5, 32.0, 4.9, 156.7, 1.2, 4.1, 0.7, 2.0, 1.4, 14.3, 0.7, 5.0, 32.9, 34.6, 115.1]
# HoldingCostsPerUnit1
# [1.552, 1.003, 1.141, 0.366, 0.379, 1.343, 0.853, 1.527, 1.271, 1.418, 1.356, 1.334, 0.727, 1.537, 0.654, 0.817, 0.92, 1.185, 0.353, 1.483, 1.298, 1.719, 0.396, 1.166, 0.343, 1.251, 0.798, 0.456, 1.557, 1.541, 1.521, 0.789, 0.469, 1.432, 0.663, 1.645, 0.644, 0.259, 0.562, 1.483, 1.237, 1.674, 0.946, 0.832, 0.854, 1.035, 0.68, 1.131, 0.388, 1.462, 0.288, 1.429, 0.699, 0.833, 0.825, 0.582, 0.965, 0.802, 1.596, 0.719, 0.674, 1.618, 0.628, 1.381, 1.653, 0.371, 0.78, 0.889, 0.265, 0.997, 1.742, 0.621, 1.305, 1.159, 1.651, 1.095, 0.518, 0.457, 1.313, 0.84, 1.105, 1.723, 1.383, 0.905, 1.562, 0.405, 0.665, 0.358, 1.748, 1.475, 0.751, 1.435, 1.086, 0.881, 1.487, 0.752, 1.132, 1.566, 1.411, 0.764]
# MinorOrderingCosts1
# [172.1, 173.8, 33.8, 60.3, 150.4, 96.4, 85.3, 99.4, 39.3, 141.8, 34.3, 155.9, 72.7, 143.7, 174.5, 81.7, 61.0, 157.1, 143.5, 48.2, 40.8, 95.6, 39.6, 52.6, 147.8, 121.6, 128.2, 77.5, 109.7, 62.2, 73.0, 78.9, 161.4, 167.2, 57.6, 82.3, 64.4, 25.9, 56.2, 143.9, 32.9, 61.6, 46.7, 120.2, 158.1, 103.5, 68.0, 116.7, 34.8, 146.2, 73.8, 94.9, 87.4, 100.0, 173.7, 58.2, 137.2, 104.4, 159.6, 71.9, 64.3, 117.2, 44.3, 26.1, 48.8, 98.8, 106.2, 88.9, 140.5, 86.7, 71.5, 135.7, 75.0, 132.9, 165.1, 26.5, 80.8, 47.0, 164.8, 49.1, 124.3, 127.5, 138.3, 156.0, 156.2, 40.5, 100.9, 60.1, 174.8, 147.5, 135.2, 85.4, 108.6, 28.2, 45.8, 149.6, 174.2, 156.6, 106.0, 125.9]
# 100

# %%
# Modelling optimization function
# def objective(x):
#      return [x[0] * x[3] * D[0] * 0.5 * h[0] + (1 / x[3]) * (S + s[0] / x[0])
#             +x[1] * x[3] * D[1] * 0.5 * h[1] + (1 / x[3]) * (S + s[1] / x[1])
#             +x[2] * x[3] * D[2] * 0.5 * h[2] + (1 / x[3]) * (S + s[2] / x[2])]
  
def objective(x):
     return sum((x[0:items] * x[items] * D[0:items] * 0.5 * h[0:items])
              + (1 / x[items]) * (s[0:items] / x[0:items])) + (1 / x[items]) * S

# def constraint1(x):
#     return x[0]+x[1]+x[2]+x[3]-4.0

# def constraint2(x):
#     sum_eq = 40.0
#     for i in range(4):
#         sum_eq = sum_eq - x[i]**2
#     return sum_eq


# Define decision variables and initialize parameters
n = items + 1
x0 = np.zeros(n) # the number of integer multipliers of T that a replensishment of item i will last
for i in range(items):
    x0[i] = 1.0
x0[items] = 20 # T

# show initial objective
print('Initial Objective: ' + str(objective(x0)))

# optimize
# b = (1.0,5.0)
# bnds = (b, b, b, b)
bnds = []
for i in range(items + 1):
    bnds.append([1.0,5.0])

# con1 = {'type': 'ineq', 'fun': constraint1} 
# con2 = {'type': 'eq', 'fun': constraint2}
# cons = ([con1])
# cons = ([con1,con2])

# SLSQP only solver can solve nonlinear 
solution = minimize(objective,x0,method='SLSQP',\
                    bounds=bnds)
x = solution.x

# show final objective
print('Final Objective: ' + str(objective(x)))

# print solution
print('Solution')
for i in range(items):
     print(str(x[i]))
#     print('x{} = '.format(i) + str(x[i]))
print('T = ' + str(x[items]))
# Out:
# Initial Objective: 46701.57600000001
# Final Objective: 14314.351657035284
# Solution
# 1.108342240050991
# 1.000000000039468
# 1.0000000000068243
# 1.000000000009724
# 1.4087734858531025
# 1.4370894340514366
# 1.0000000000126146
# 1.0000000000392097
# 1.000000000002042
# 1.0000000000243072
# 1.000000000018973
# 1.0000000000049647
# 1.1220042544317883
# 1.0000000000531215
# 3.545624068608445
# 1.0000000000059217
# 4.9999999999999565
# 2.8987324666538457
# 2.7166626210736635
# 1.0000000000157228
# 1.5770933914703449
# 1.0000000000169111
# 1.8327723425133327
# 1.0000000000018896
# 3.4115643041028414
# 1.0000000000110045
# 1.252160551317603
# 1.8017672532443554
# 1.0000000000467615
# 1.0000000000266545
# 2.5784997415030055
# 1.000000000000468
# 1.6022233081351835
# 1.0000000000511384
# 1.1897160742794237
# 3.329415196582324
# 1.2763533125582922
# 2.7177361025026294
# 1.236218742310239
# 1.0000000000249176
# 1.0000000000033202
# 1.0000000000497486
# 2.794974491293723
# 1.0000000000321456
# 1.0000000000027194
# 1.3940751151588382
# 1.0000000000042748
# 1.00000000001661
# 1.0000000000065121
# 1.000000000002643
# 1.025362256270135
# 1.0000000000051659
# 1.2405804962884779
# 1.0000000000232918
# 4.712891095502439
# 1.0000000000157643
# 1.0606825955196164
# 1.0984904077240585
# 1.8321418748466343
# 2.9768373101894374
# 2.530810712827857
# 1.0000000000224978
# 1.2086233160657285
# 1.6169124203886887
# 1.5283974485747112
# 2.2359136535751483
# 1.3399487717259042
# 1.0000000000170837
# 2.048202235817097
# 2.776254568148604
# 1.0051953070711153
# 1.7788246999957271
# 1.0000000000031262
# 1.0000000000016995
# 1.000000000001815
# 1.000000000003474
# 4.999999999999898
# 1.0000000000150462
# 1.000000000028736
# 1.0000000000070886
# 1.000000000006117
# 1.0000000000180083
# 4.70678293933808
# 1.5851001031756602
# 1.24030411741999
# 2.977102403401091
# 1.02494337141512
# 2.7549258550199296
# 1.0000000000595097
# 4.296656013341413
# 3.1189195918941586
# 4.339930595639958
# 3.328042532611851
# 2.250739089185227
# 1.0000000000028129
# 4.9999999999997975
# 2.6112224669391515
# 1.0000000000042575
# 1.0000000000064109
# 1.000000000015193
# T = 3.004545982706737

# %%
print(1*1*10*0.5*2 - 0.001 * 5 * (10 + 0.001*2*1))
# Out:
# 9.94999

# %%
def objective(x):
     return [x[0] * x[3] * D[0] * 0.5 * h[0] + (1 / x[3]) * (s[0] / x[0])
            +x[1] * x[3] * D[1] * 0.5 * h[1] + (1 / x[3]) * (s[1] / x[1])
            +x[2] * x[3] * D[2] * 0.5 * h[2] + (1 / x[3]) * (s[2] / x[2]) + (1 / x[3]) * S]

# %%
# Define decision variables and initialize parameters
n = items + 1
x0 = np.zeros(n) # the number of integer multipliers of T that a replensishment of item i will last
for i in range(items):
    x0[i] = 1.0
x0[items] = 5 # T

# show initial objective
print('Initial Objective: ' + str(objective(x0)))
# Out:
# Initial Objective: [2955.8]
